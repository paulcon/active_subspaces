# %% [markdown]
# # USE CASE: Optimization for two-dimensional active subspace.

# %% [markdown]
# A quadratic function to study. The user provides this. It is usually a call to some simulation code---not a python function.

# %%
import numpy as np
import active_subspaces as ac
import matplotlib.pyplot as plt
from scipy.spatial import convex_hull_plot_2d

class MyQuadratic():
    def __init__(self):
        self.e = np.exp(np.array([2,1,-2,-3,-4,-5,-6,-7,-8,-9.]))
        self.W = np.linalg.qr(np.random.normal(size=(10,10)))[0]
        self.A = np.dot(self.W,np.dot(np.diag(self.e),self.W.T))
    def __call__(self,x):
        return 0.5*np.dot(x,np.dot(self.A,x.T)),np.dot(self.A,x.T)
    def integral(self):
        return (1./6.)*np.sum(np.diag(self.A))

fun = MyQuadratic()

# %% [markdown]
# Discover the active subspace of the function.

# %%
M,m = 100,10
X = np.random.uniform(-1.,1.,size=(M,m))

# sample the function. often done offline. 'sample_function' is just for convenience
F,dF = ac.sample_function(X,fun,dflag=True)

# compute the active subspace components
k = 6
e,W,e_br,sub_br = ac.compute_active_subspace(dF,k,n_boot=1000)

# make some plots
asp = ac.ActiveSubspacePlotter()
asp.eigenvalues(e,e_br=e_br)
asp.subspace_errors(sub_br)
asp.eigenvectors(W[:,:6])
y = np.dot(X,W[:,0])
asp.sufficient_summary(y,F)

# %% [markdown]
# Get the response surface design and plot its points.

# %%
# Get a design on the active variable
n = 2 # dimension of the active subspace
N = [10] # number points in the active variable
NMC = 10 # number of monte carlo samples
XX,ind,Y = ac.response_surface_design(W,n,N,NMC,bflag=1)

# look at the zonotope and the design
zt = ac.Zonotope(W[:,:n])
convex_hull_plot_2d(zt.convhull)
plt.plot(Y[:,0],Y[:,1],'ro')
plt.xlabel('Active variable 1')
plt.ylabel('Active variable 2')
plt.show()

# %%
# sample the function at the design points
FF = ac.sample_function(XX,fun,dflag=True)[0]

# compute conditional expectations
G,V = ac.conditional_expectations(FF,ind)

# build the response surface on the active variable
gp = ac.GaussianProcess(2)
gp.train(Y,G,e=e,gl=0.0,gu=10.0,v=V)

# %% [markdown]
# Optimize on the active variables.

# %%
# set up the functions for the optimization
import pdb
def fun(x):
    n = x.size
    return gp.predict(x.reshape((1,n)))[0]
def dfun(x):
    n = x.size
    return gp.predict(x.reshape((1,n)),compgrad=True)[1]

# get constraints from the zonotope
cons = zt.constraints()

# run optimization
from scipy.optimize import minimize
y0 = np.random.normal(size=(1,n))
res = minimize(fun,y0,constraints=cons,jac=dfun,method='SLSQP',
                options={'disp':True,'maxiter':1e4,'ftol':1e-9})
print y0
print res
# Out:
# Iteration limit exceeded    (Exit mode 9)
#             Current function value: [[-0.21668447]]
#             Iterations: 10001
#             Function evaluations: 109974
#             Gradient evaluations: 10001
# [[-0.25962198  0.85378129]]
#   status: 9
#  success: False
#     njev: 10001
#     nfev: 109974
#      fun: array([[-0.21668447]])
#        x: array([ 0.05000452,  0.02563493])
#  message: 'Iteration limit exceeded'
#      jac: array([ 0.1492747 , -0.10523843,  0.        ])
#      nit: 10001

# %%
# Out:
# > <ipython-input-14-11bfcf0cbac2>(9)dfun()
# -> n = x.size
# (Pdb) s
# > <ipython-input-14-11bfcf0cbac2>(10)dfun()
# -> return gp.predict(x.reshape((1,n)),compgrad=True)[1]
# (Pdb) s
# --Call--
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(105)predict()
# -> def predict(self,Xstar,compgrad=False,compvar=False):
# (Pdb) s
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(106)predict()
# -> try:
# (Pdb) s
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(107)predict()
# -> M,m = Xstar.shape
# (Pdb)
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(112)predict()
# -> Kstar = exponential_squared_covariance(self.X,Xstar,self.sig,self.ell)
# (Pdb)
# --Call--
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(173)exponential_squared_covariance()
# -> def exponential_squared_covariance(X1,X2,sigma,ell):
# (Pdb)
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(174)exponential_squared_covariance()
# -> m = X1.shape[0]
# (Pdb)
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(175)exponential_squared_covariance()
# -> n = X2.shape[0]
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(176)exponential_squared_covariance()
# -> c = -1.0/ell.flatten()
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(177)exponential_squared_covariance()
# -> C = np.zeros((m,n))
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(178)exponential_squared_covariance()
# -> for i in range(n):
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(179)exponential_squared_covariance()
# -> x2 = X2[i,:]
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(180)exponential_squared_covariance()
# -> B = X1 - x2
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(181)exponential_squared_covariance()
# -> C[:,i] = sigma*np.exp(np.dot(B*B,c))
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(178)exponential_squared_covariance()
# -> for i in range(n):
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(182)exponential_squared_covariance()
# -> return C
# (Pdb) n
# --Return--
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(182)exponential_squared_covariance()->array([[...519376]])
# -> return C
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(113)predict()
# -> fstar = np.dot(Kstar.T,self.f_weights)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(116)predict()
# -> Pstar = np.linalg.solve(self.K,Kstar)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(117)predict()
# -> Bstar = polynomial_bases(Xstar,self.N)[0]
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(118)predict()
# -> Rstar = Bstar - np.dot(Pstar.T,self.B)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(119)predict()
# -> fstar += np.dot(Rstar,self.p_weights)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(121)predict()
# -> if compgrad:
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(122)predict()
# -> dKstar = grad_exponential_squared_covariance(self.X,Xstar,self.sig,self.ell)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(123)predict()
# -> dBstar = grad_polynomial_bases(Xstar,self.N)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(124)predict()
# -> dfstar = np.zeros((M,m))
# (Pdb) print M,m
# 1 2
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(125)predict()
# -> for i in range(m):
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(126)predict()
# -> dPstar = np.linalg.solve(self.K,dKstar[:,:,i])
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(127)predict()
# -> dRstar = dBstar[:,:,i] - np.dot(dPstar.T,self.B)
# (Pdb) n
# > /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.py(128)predict()
# -> dfstar[:,i] = (np.dot(dKstar.T,self.f_weights) \
# (Pdb) AA = np.dot(dKstar.T,self.f_weights) + np.dot(dRstar,self.p_weights)
# (Pdb) print AA
# [[[ 9.37372197]]
#
#  [[-1.87270303]]]
# (Pdb) print dRstar.shape
# (1, 6)
# (Pdb) print dKstar.shape
# (30, 1, 2)
# (Pdb) print self.p_weights.shape
# (6, 1)
# (Pdb) print self.p_weights
# [[ 3.86670458]
#  [-0.34787051]
#  [ 0.444488  ]
#  [ 2.74194548]
#  [-0.54769005]
#  [ 1.19505987]]
# (Pdb) print self.f_weights
# [[  8.87014002]
#  [ -7.41289114]
#  [ -4.63579258]
#  [-25.69476093]
#  [ -6.36403875]
#  [ -1.22687775]
#  [ 19.80156944]
#  [  8.70465706]
#  [-16.12520615]
#  [  6.67996954]
#  [  6.58523729]
#  [  6.88655315]
#  [ 10.02740063]
#  [  6.12105624]
#  [  7.23185701]
#  [  3.89936792]
#  [  6.3318178 ]
#  [ 26.04506154]
#  [ -8.54202475]
#  [ 21.96557896]
#  [ 10.89157342]
#  [ 12.66237083]
#  [-17.49208606]
#  [-11.21951276]
#  [-16.15022433]
#  [ -4.9983466 ]
#  [  1.23349677]
#  [  6.41664627]
#  [-24.12405952]
#  [-23.86153578]]
# (Pdb) print dKstar.shape
# (30, 1, 2)
# (Pdb) exit
# ---------------------------------------------------------------------------
# BdbQuit                                   Traceback (most recent call last)
# <ipython-input-15-86d26d459492> in <module>()
# ----> 1 print dfun(y0)
#
# <ipython-input-14-11bfcf0cbac2> in dfun(x)
#       8     pdb.set_trace()
#       9     n = x.size
# ---> 10     return gp.predict(x.reshape((1,n)),compgrad=True)[1]
#      11
#      12 # get constraints from the zonotope
#
# /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.pyc in predict(self, Xstar, compgrad, compvar)
#     126                 dPstar = np.linalg.solve(self.K,dKstar[:,:,i])
#     127                 dRstar = dBstar[:,:,i] - np.dot(dPstar.T,self.B)
# --> 128                 dfstar[:,i] = (np.dot(dKstar[:,:,i].T,self.f_weights) \
#     129                     + np.dot(dRstar,self.p_weights)).reshape((M))
#     130         else:
#
# /Users/constantine/Dropbox/Codes/python/path/active_subspaces/regression.pyc in predict(self, Xstar, compgrad, compvar)
#     126                 dPstar = np.linalg.solve(self.K,dKstar[:,:,i])
#     127                 dRstar = dBstar[:,:,i] - np.dot(dPstar.T,self.B)
# --> 128                 dfstar[:,i] = (np.dot(dKstar[:,:,i].T,self.f_weights) \
#     129                     + np.dot(dRstar,self.p_weights)).reshape((M))
#     130         else:
#
# /Applications/Canopy.app/appdata/canopy-1.5.1.2730.macosx-x86_64/Canopy.app/Contents/lib/python2.7/bdb.pyc in trace_dispatch(self, frame, event, arg)
#      47             return # None
#      48         if event == 'line':
# ---> 49             return self.dispatch_line(frame)
#      50         if event == 'call':
#      51             return self.dispatch_call(frame, arg)
#
# /Applications/Canopy.app/appdata/canopy-1.5.1.2730.macosx-x86_64/Canopy.app/Contents/lib/python2.7/bdb.pyc in dispatch_line(self, frame)
#      66         if self.stop_here(frame) or self.break_here(frame):
#      67             self.user_line(frame)
# ---> 68             if self.quitting: raise BdbQuit
#      69         return self.trace_dispatch
#      70
#
# BdbQuit:
