# %%
import numpy as np
import active_subspaces as asub

# %%
m, n = 5, 2
W = np.linalg.qr(np.random.normal(size=(m, m)))[0]
W1 = W[:,:n]
Y = asub.domains.zonotope_vertices(W1)[0]
asub.utils.plotters.zonotope_2d_plot(Y)
